# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/List_of_country_calling_codes')

# %%
df
# Out:
# [   Unnamed: 0                                              x = 0  \
#  0         NaN                                                NaN
#  1          1x  +1: North American Numbering Plan countries an...
#  2          1x                                                NaN
#  3         NaN                                                NaN
#  4          2x                                            +20: EG
#  5         21x                                            +210: —
#  6         22x                                           +220: GM
#  7         23x                                           +230: MU
#  8         24x                                           +240: GQ
#  9         25x                                           +250: RW
#  10        26x                                           +260: ZM
#  11        29x                                       +290: SH, TA
#  12        NaN                                                NaN
# ...

# %%
type(df)
# Out:
# list

# %%
df[0]
# Out:
#    Unnamed: 0                                              x = 0  \
# 0         NaN                                                NaN
# 1          1x  +1: North American Numbering Plan countries an...
# 2          1x                                                NaN
# 3         NaN                                                NaN
# 4          2x                                            +20: EG
# 5         21x                                            +210: —
# 6         22x                                           +220: GM
# 7         23x                                           +230: MU
# 8         24x                                           +240: GQ
# 9         25x                                           +250: RW
# 10        26x                                           +260: ZM
# 11        29x                                       +290: SH, TA
# 12        NaN                                                NaN
# ...

# %%
df[1]
# Out:
#     Country, Territory or Service     Code  Time Zone        DST
# 0                     Afghanistan      +93  UTC+04:30        NaN
# 1                           Åland  +358 18  UTC+02:00  UTC+03:00
# 2                         Albania     +355  UTC+01:00  UTC+02:00
# 3                         Algeria     +213  UTC+01:00        NaN
# 4                  American Samoa   +1 684  UTC−11:00        NaN
# ..                            ...      ...        ...        ...
# 275             Wallis and Futuna     +681  UTC+12:00        NaN
# 276                         Yemen     +967  UTC+03:00        NaN
# 277                        Zambia     +260  UTC+02:00        NaN
# 278                      Zanzibar  +255 24  UTC+03:00        NaN
# 279                      Zimbabwe     +263  UTC+02:00        NaN
#
# [280 rows x 4 columns]

# %%
type(df[1])
# Out:
# pandas.core.frame.DataFrame
